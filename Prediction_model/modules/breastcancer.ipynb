# %%
pip install pandas scikit-learn pickle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
breastcancer_dataset = pd.read_csv("../datasets/breastcancer.csv")

# %%
breastcancer_dataset.head()
# Out:
#    Age  RadiusMean  TextureMean  PerimeterMean  AreaMean  SmoothnessMean  \
# 0   45        12.3         18.5           78.5       481           0.092
# 1   50        10.5         16.2           65.3       345           0.085
# 2   55        14.1         20.3           85.7       520           0.100
# 3   60        11.2         17.8           70.4       400           0.090
# 4   65        13.5         19.6           82.3       500           0.095
#
#    CompactnessMean  ConcavityMean  ConcavePointsMean  SymmetryMean  ...  \
# 0            0.075          0.042              0.024         0.163  ...
# 1            0.060          0.030              0.018         0.150  ...
# 2            0.080          0.050              0.030         0.170  ...
# 3            0.070          0.040              0.022         0.160  ...
# 4            0.075          0.045              0.026         0.165  ...
#
#    TextureWorst  PerimeterWorst  AreaWorst  SmoothnessWorst  CompactnessWorst  \
# ...

# %%
breastcancer_dataset.shape
# Out:
# (168, 32)

# %%
breastcancer_dataset.describe()
# Out:
#               Age  RadiusMean  TextureMean  PerimeterMean    AreaMean  \
# count  168.000000  168.000000   168.000000     168.000000  168.000000
# mean    54.291667   12.433333    18.701190      77.126786  460.190476
# std      8.801438    1.590867     1.855175       9.009745   81.026938
# min     40.000000    9.800000    15.500000      60.200000  320.000000
# 25%     48.000000   11.200000    17.800000      70.400000  400.000000
# 50%     53.500000   12.300000    18.500000      78.500000  480.500000
# 75%     60.000000   13.500000    19.800000      83.100000  510.000000
# max     70.000000   15.200000    22.100000      90.500000  600.000000
#
#        SmoothnessMean  CompactnessMean  ConcavityMean  ConcavePointsMean  \
# count      168.000000       168.000000     168.000000         168.000000
# mean         0.092280         0.071458       0.040774           0.023893
# std          0.006981         0.008842       0.008808           0.005720
# ...

# %%
breastcancer_dataset['Outcome']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 163    0
# 164    1
# 165    0
# 166    1
# 167    0
# Name: Outcome, Length: 168, dtype: int64

# %%
breastcancer_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 1    100
# 0     68
# Name: count, dtype: int64

# %%
breastcancer_dataset['Outcome'].mean()
# Out:
# 0.5952380952380952

# %%
x = breastcancer_dataset.drop(columns=['Outcome'], axis=1)
y = breastcancer_dataset['Outcome']

# %%
x.head()
# Out:
#    Age  RadiusMean  TextureMean  PerimeterMean  AreaMean  SmoothnessMean  \
# 0   45        12.3         18.5           78.5       481           0.092
# 1   50        10.5         16.2           65.3       345           0.085
# 2   55        14.1         20.3           85.7       520           0.100
# 3   60        11.2         17.8           70.4       400           0.090
# 4   65        13.5         19.6           82.3       500           0.095
#
#    CompactnessMean  ConcavityMean  ConcavePointsMean  SymmetryMean  ...  \
# 0            0.075          0.042              0.024         0.163  ...
# 1            0.060          0.030              0.018         0.150  ...
# 2            0.080          0.050              0.030         0.170  ...
# 3            0.070          0.040              0.022         0.160  ...
# 4            0.075          0.045              0.026         0.165  ...
#
#    RadiusWorst  TextureWorst  PerimeterWorst  AreaWorst  SmoothnessWorst  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (134, 31)

# %%
x_test.shape
# Out:
# (34, 31)

# %%
x_train.head()
# Out:
#      Age  RadiusMean  TextureMean  PerimeterMean  AreaMean  SmoothnessMean  \
# 69    58        13.2         19.8           83.1       510           0.097
# 136   70        15.2         22.1           90.5       600           0.105
# 2     55        14.1         20.3           85.7       520           0.100
# 93    60        11.2         17.8           70.4       400           0.090
# 134   65        13.5         19.6           82.3       500           0.095
#
#      CompactnessMean  ConcavityMean  ConcavePointsMean  SymmetryMean  ...  \
# 69             0.078          0.048              0.028         0.168  ...
# 136            0.085          0.055              0.035         0.180  ...
# 2              0.080          0.050              0.030         0.170  ...
# 93             0.070          0.040              0.022         0.160  ...
# 134            0.075          0.045              0.026         0.165  ...
#
# ...

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 1.0

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle
filename = 'breastcancer_model.sav'
pickle.dump(model,open(filename,'wb'))
