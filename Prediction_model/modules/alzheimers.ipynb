# %%
pip install pandas scikit-learn pickle
# Out:
# ...
#      -------------------------------------- 11.2/11.2 MB 798.7 kB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# WARNING: You are using pip version 22.0.4; however, version 25.0 is available.
# You should consider upgrading via the 'C:\Users\anand\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
alzheimers_dataset = pd.read_csv("../datasets/alzheimers.csv")

# %%
alzheimers_dataset.head()
# Out:
#    Age  Gender  CognitiveTestScore  BrainScanResult  FamilyHistory  Outcome
# 0   70       1                  18             0.45              1        1
# 1   65       0                  22             0.67              0        0
# 2   80       1                  15             0.32              1        1
# 3   55       0                  25             0.78              0        0
# 4   75       1                  17             0.50              1        1

# %%
alzheimers_dataset.shape
# Out:
# (168, 6)

# %%
alzheimers_dataset.describe()
# Out:
#               Age      Gender  CognitiveTestScore  BrainScanResult  \
# count  168.000000  168.000000          168.000000       168.000000
# mean    68.380952    0.500000           19.547619         0.568036
# std      8.112096    0.501495            4.158261         0.181254
# min     54.000000    0.000000           11.000000         0.220000
# 25%     62.000000    0.000000           16.000000         0.370000
# 50%     69.000000    0.500000           20.000000         0.605000
# 75%     75.000000    1.000000           22.000000         0.712500
# max     82.000000    1.000000           28.000000         0.850000
#
#        FamilyHistory     Outcome
# count     168.000000  168.000000
# mean        0.589286    0.511905
# std         0.493434    0.501353
# min         0.000000    0.000000
# 25%         0.000000    0.000000
# 50%         1.000000    1.000000
# 75%         1.000000    1.000000
# max         1.000000    1.000000

# %%
alzheimers_dataset['Outcome']
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 163    1
# 164    0
# 165    1
# 166    0
# 167    0
# Name: Outcome, Length: 168, dtype: int64

# %%
alzheimers_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 1    86
# 0    82
# Name: count, dtype: int64

# %%
alzheimers_dataset['Outcome'].mean()
# Out:
# 0.5119047619047619

# %%
x = alzheimers_dataset.drop(columns=['Outcome'], axis=1)
y = alzheimers_dataset['Outcome']

# %%
x.head()
# Out:
#    Age  Gender  CognitiveTestScore  BrainScanResult  FamilyHistory
# 0   70       1                  18             0.45              1
# 1   65       0                  22             0.67              0
# 2   80       1                  15             0.32              1
# 3   55       0                  25             0.78              0
# 4   75       1                  17             0.50              1

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (134, 5)

# %%
x_test.shape
# Out:
# (34, 5)

# %%
x_train.head()
# Out:
#      Age  Gender  CognitiveTestScore  BrainScanResult  FamilyHistory
# 69    78       0                  14             0.30              1
# 136   80       1                  14             0.32              1
# 2     80       1                  15             0.32              1
# 93    64       0                  22             0.69              0
# 134   74       1                  19             0.55              1

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9411764705882353

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle
filename = 'alzheimers.sav'
pickle.dump(model,open(filename,'wb'))
